# %%
import matplotlib
import numpy as np
import sklearn
import pandas 
import math
import matplotlib.pyplot as plt

# %%
classes = ["MSSubClass","MSZoning","LotFrontage","LotArea","Street","Alley","LotShape","LandContour","Utilities",
           "LotConfig","LandSlope","Neighborhood","Condition1","Condition2","BldgType","HouseStyle","OverallQual",
           "OverallCond","YearBuilt","YearRemodAdd","RoofStyle","RoofMatl","Exterior1st","Exterior2nd","MasVnrType",
           "MasVnrArea","ExterQual","ExterCond","Foundation","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1",
           "BsmtFinSF1","BsmtFinType2","BsmtFinSF2","BsmtUnfSF","TotalBsmtSF","Heating","HeatingQC","CentralAir",
           "Electrical","1stFlrSF","2ndFlrSF","LowQualFinSF","GrLivArea","BsmtFullBath","BsmtHalfBath","FullBath",
           "HalfBath","Bedroom","Kitchen","KitchenQual","TotRmsAbvGrd","Functional","Fireplaces","FireplaceQu",
           "GarageType","GarageYrBlt","GarageFinish","GarageCars","GarageArea","GarageQual","GarageCond","PavedDrive",
           "WoodDeckSF","OpenPorchSF","EnclosedPorch","3SsnPorch","ScreenPorch","PoolArea","PoolQC","Fence",
           "MiscFeature","MiscVal","MoSold","YrSold","SaleType","SaleCondition","SalePrice"]

# %%
data_train = pandas.read_csv("C:\\Users\\Admin\\Downloads\\train2.csv", header = None, names = classes)

# %%
data_train.drop(data_train.index[0], inplace=True)
# Out:
#      MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape  \
# 1            60       RL          65    8450   Pave     0      Reg
# 2            20       RL          80    9600   Pave     0      Reg
# 3            60       RL          68   11250   Pave     0      IR1
# 4            70       RL          60    9550   Pave     0      IR1
# 5            60       RL          84   14260   Pave     0      IR1
# 6            50       RL          85   14115   Pave     0      IR1
# 7            20       RL          75   10084   Pave     0      Reg
# 8            60       RL           0   10382   Pave     0      IR1
# 9            50       RM          51    6120   Pave     0      Reg
# 10          190       RL          50    7420   Pave     0      Reg
# 11           20       RL          70   11200   Pave     0      Reg
# 12           60       RL          85   11924   Pave     0      IR1
# 13           20       RL           0   12968   Pave     0      IR2
# ...

# %%
data_train2 = data_train.drop(columns = ["MSZoning","LotFrontage","Street","Alley","LotShape",
                                         "LandContour","Utilities","LotConfig","LandSlope",
                "Neighborhood","Condition1","Condition2","BldgType","HouseStyle","RoofStyle","RoofMatl","Exterior1st",
                "Exterior2nd","MasVnrType","ExterQual","ExterCond","Foundation","BsmtQual","BsmtCond","BsmtExposure",
                "BsmtFinType1","BsmtFinType2","Heating","HeatingQC","CentralAir","Electrical","KitchenQual","Functional",
                "FireplaceQu","GarageType","GarageFinish","GarageQual","GarageCond","PavedDrive","PoolQC","Fence",
                "MiscFeature","SaleType","SaleCondition"])

# %%
df = pandas.DataFrame(data_train2)
# Out:
#      MSSubClass LotArea OverallQual OverallCond YearBuilt YearRemodAdd  \
# 1            60    8450           7           5      2003         2003
# 2            20    9600           6           8      1976         1976
# 3            60   11250           7           5      2001         2002
# 4            70    9550           7           5      1915         1970
# 5            60   14260           8           5      2000         2000
# 6            50   14115           5           5      1993         1995
# 7            20   10084           8           5      2004         2005
# 8            60   10382           7           6      1973         1973
# 9            50    6120           7           5      1931         1950
# 10          190    7420           5           6      1939         1950
# 11           20   11200           5           5      1965         1965
# 12           60   11924           9           5      2005         2006
# ...

# %%
df.to_csv('out.csv')

# %%
Sale_Price_Sample = df.SalePrice.sample(5)
Lot_Area_Sample = df.LotArea.sample(5)
Fireplaces_Sample = df.Fireplaces.sample(5)
GarageArea_Sample = df.GarageArea.sample(5)
GrLivArea_Sample =df.GrLivArea.sample(5)
BsmtFinSF1_Sample = df.BsmtFinSF1.sample(5)

# %%
plt.scatter(Sale_Price_Sample,Lot_Area_Sample, label ="skitscat",color="k")
plt.xlabel("Sale Price")
plt.ylabel("Lot Area")
plt.title("House prices over the years")
plt.legend("")
plt.show()
plt.savefig('output.png', transparent =True, bbox_inches="tight")

# %%
plt.scatter(Sale_Price_Sample,Fireplaces_Sample, label ="skitscat",color="k")
plt.xlabel("Sale Price")
plt.ylabel("Firplaces")
plt.title("House prices to fireplaces")
plt.legend("")
plt.show()

# %%
plt.scatter(Sale_Price_Sample,GarageArea_Sample, label ="skitscat",color="k")
plt.xlabel("Sale Price")
plt.ylabel("Garage")
plt.title("House prices to Garages")
plt.legend("")
plt.show()

# %%
plt.scatter(Sale_Price_Sample,GrLivArea_Sample, label ="skitscat",color="k")
plt.xlabel("Sale Price")
plt.ylabel("Ground Living Area")
plt.title("House prices to ground living area")
plt.legend("")
plt.show()

# %%
plt.scatter(Sale_Price_Sample,BsmtFinSF1_Sample, label ="skitscat",color="k")
plt.xlabel("Sale Price")
plt.ylabel("Basement Squared Feet")
plt.title("House prices to basement area")
plt.legend("")
plt.show()

# %%
df1 = df[[int(0),int(1)]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-4ec537a587f3> in <module>()
# ----> 1 df1 = df[[int(0),int(1)]]
#
# c:\users\admin\miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# c:\users\admin\miniconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# ...
